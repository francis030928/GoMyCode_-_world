# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
boston = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/Data Sets/boston.csv')
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
new_boston = boston[['INDUS','TAX']]
new_boston
# Out:
#      INDUS    TAX
# 0     2.31  296.0
# 1     7.07  242.0
# 2     7.07  242.0
# 3     2.18  222.0
# 4     2.18  222.0
# ..     ...    ...
# 501  11.93  273.0
# 502  11.93  273.0
# 503  11.93  273.0
# 504  11.93  273.0
# 505  11.93  273.0
#
# [506 rows x 2 columns]

# %%
2.18 + (2.18 * 0.01)
# Out:
# 2.2018

# %%
222 +(222*0.17)
# Out:
# 259.74

# %%
plt.figure(figsize = (10, 7))
sns.set(style = 'darkgrid')
sns.regplot(new_boston.INDUS, new_boston.TAX, ci = None, color = 'red')
plt.xlabel('INDUS	')
plt.ylabel('TAX')
plt.show()

# %%
sim = LinearRegression()
model = sim.fit(boston[['INDUS']], boston[['TAX']])

# %%
tax_test = [[18]]
pred = model.predict(tax_test)
pred
# Out:
# array([[529.76278646]])

# %%
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
# Out:
# Coefficients: [[17.70679193]]
# Intercept: [211.04053171]

# %% [markdown]
# This interprets that:
# - The actual tax, if all independent variables where zero, 211.04053171
# - A 1% increase in the industrial acre of land leads to a 17% in tax
